# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from os import system
#!wget https://drive.google.com/file/d/14nqjmhWH00nLQ6XvAnzdhJu8W0sQoXTO/view?usp=sharing
#system("unzip Copy_of_Merged_Datasets.zip -d sep-28k_dataset")

# %%
# !unzip /content/gdrive/MyDrive/Omdena_2/Copy_of_Merged_Datasets.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Merged_Datasets/Tomato Spider mites Two spotted spider mite/Tomato_Spider_mites_Two_spotted_spider_mite1412.jpg
#   inflating: Merged_Datasets/Tomato Spider mites Two spotted spider mite/Tomato_Spider_mites_Two_spotted_spider_mite1413.jpg
#   inflating: Merged_Datasets/Tomato Spider mites Two spotted spider mite/Tomato_Spider_mites_Two_spotted_spider_mite1414.jpg
#   inflating: Merged_Datasets/Tomato Spider mites Two spotted spider mite/Tomato_Spider_mites_Two_spotted_spider_mite1415.jpg
#   inflating: Merged_Datasets/Tomato Spider mites Two spotted spider mite/Tomato_Spider_mites_Two_spotted_spider_mite1416.jpg
#   inflating: Merged_Datasets/Tomato Spider mites Two spotted spider mite/Tomato_Spider_mites_Two_spotted_spider_mite1417.jpg
#   inflating: Merged_Datasets/Tomato Spider mites Two spotted spider mite/Tomato_Spider_mites_Two_spotted_spider_mite1418.jpg
# ...

# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 256
CHANNELS = 3
EPOCHS=2

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "Merged_Datasets",
    shuffle = True,  #for shuffling,
    image_size = (IMAGE_SIZE,IMAGE_SIZE),
    batch_size = BATCH_SIZE
)
# Out:
# Found 50440 files belonging to 49 classes.

# %%
len(dataset)   

# 1577 batches total
# Out:
# 1577

# %%
class_namess = dataset.class_names
len(class_namess)
# Out:
# 49

# %%
import os

pathh = "/content/Merged_Datasets"
image_number=[]
disease =[]
for k in class_namess:
    full_path = pathh+'/'+k
    lst = os.listdir(full_path) # your directory path
    #print(lst,"sdffdfv")
    number_files = len(lst)
    image_number.append(number_files)
    disease.append(k)
    print(number_files," images in",k,"floder")
# Out:
# 2016  images in Apple Apple scab floder
# 1988  images in Apple Black rot floder
# 880  images in Apple Cedar apple rust floder
# 1645  images in Apple healthy floder
# 1502  images in Blueberry healthy floder
# 1052  images in Cherry Powdery mildew floder
# 853  images in Cherry healthy floder
# 574  images in Corn Gray Leaf Spot floder
# 1146  images in Corn Leaf Blight floder
# 1306  images in Corn Leaf Common Rust floder
# 985  images in Corn Northern Leaf Blight floder
# 1162  images in Corn healthy floder
# 1180  images in Grape Black rot floder
# 1383  images in Grape Esca (Black Measles) floder
# 1076  images in Grape Leaf blight (Isariopsis Leaf Spot) floder
# 423  images in Grape healthy floder
# 2508  images in Orange Haunglongbing (Citrus greening) floder
# 2297  images in Peach Bacterial spot floder
# 360  images in Peach healthy floder
# 997  images in Pepper bell Bacterial spot floder
# 1477  images in Pepper bell healthy floder
# ...

# %%
pip install split-folders[full]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import splitfolders

input_folder = "Merged_Datasets"


splitfolders.ratio(input_folder, output="Main_folder",
                  seed = 42, ratio = (.75,.25),
                  group_prefix=None)
# Out:
# Copying files: 50440 files [00:17, 2867.82 files/s]

# %%
dataset2 = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/Main_folder/train",
    shuffle = True,  #for shuffling,
    image_size = (IMAGE_SIZE,IMAGE_SIZE),
    batch_size = BATCH_SIZE
)
# Out:
# Found 37816 files belonging to 49 classes.

# %%
import os

pathh = "/content/Main_folder/train"
image_number=[]
disease =[]
for k in class_namess:
    full_path = pathh+'/'+k
    lst = os.listdir(full_path) # your directory path
    #print(lst,"sdffdfv")
    number_files = len(lst)
    image_number.append(number_files)
    disease.append(k)
    print(number_files," images in",k,"floder")
# Out:
# 1512  images in Apple Apple scab floder
# 1491  images in Apple Black rot floder
# 660  images in Apple Cedar apple rust floder
# 1233  images in Apple healthy floder
# 1126  images in Blueberry healthy floder
# 789  images in Cherry Powdery mildew floder
# 639  images in Cherry healthy floder
# 430  images in Corn Gray Leaf Spot floder
# 859  images in Corn Leaf Blight floder
# 979  images in Corn Leaf Common Rust floder
# 738  images in Corn Northern Leaf Blight floder
# 871  images in Corn healthy floder
# 885  images in Grape Black rot floder
# 1037  images in Grape Esca (Black Measles) floder
# 807  images in Grape Leaf blight (Isariopsis Leaf Spot) floder
# 317  images in Grape healthy floder
# 1881  images in Orange Haunglongbing (Citrus greening) floder
# 1722  images in Peach Bacterial spot floder
# 270  images in Peach healthy floder
# 747  images in Pepper bell Bacterial spot floder
# 1107  images in Pepper bell healthy floder
# 750  images in Potato Early blight floder
# ...

# %%
dataset3 = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/Main_folder/val",
    shuffle = True,  #for shuffling,
    image_size = (IMAGE_SIZE,IMAGE_SIZE),
    batch_size = BATCH_SIZE
)
# Out:
# Found 12624 files belonging to 49 classes.

# %%
# without removing

# this function fix the number of augmented images ,
import os
import cv2
from PIL import Image
import random
def aug_imgg():
    
    count = 0
    dir_path = path_of_foldd              # that dir path
    dir_list = (os.listdir(dir_path))            #file name of particular dir
    
    #print(dir_path)
    #print((dir_list))
    print(dir_list)
    for mm in range(len(dir_list)):
        #print(dir_list[mm])
        #print(mm)
        #print((dir_list))
        if dir_list[mm]=='output':
            pass
        else:
            #print(dir_path+dir_list[mm])
            file_path = (dir_path+dir_list[mm])
            #print(file_path,"\n")
            
            #print("kjhkn")
            
            im1 = Image.open(file_path,'r')
                
            if im1.mode == 'RGB':
                #print(im1.mode)
                #im1.save(dir_path+'/'+'outputt/'+dir_list[mm])  
                #print(im.shape,"sfs")
                #print(im,"dsf")
                count=count+1
                #print(dir_list[mm],'\n')
            else:
                #print(file_path)
                pass
                #os.remove(file_path)
            
    
   
    #print('file count:', count) 
    augmented_img = 700-count
    print(augmented_img,"for firsttt")
    if augmented_img<0:
        return (1)         
    elif count<700:
        return (augmented_img+1)
    else:
        return(1)
    
#aug_imgg()

# %%
"""
# Removing inculde but i m thinking like we can remove later


# this function fix the number of augmented images and handle RGBA images, MAIN-------------------------------------------------
import os
import cv2
from PIL import Image
import random
def aug_img():
    
    count = 0
    dir_path = path_of_foldd              # that dir path
    dir_list = (os.listdir(dir_path))            #file name of particular dir
    
    #print(dir_path)
    #print((dir_list))
    print(dir_list)
    for mm in range(len(dir_list)):
        #print(dir_list[mm])
        #print(mm)
        #print((dir_list))
        if dir_list[mm]=='output':
            pass
        else:
            #print(dir_path+dir_list[mm])
            file_path = (dir_path+dir_list[mm])
            #print(file_path,"\n")
            
            #print("kjhkn")
            
            im1 = Image.open(file_path,'r')
                
            if im1.mode == 'RGB':
                #print(im1.mode)
                #im1.save(dir_path+'/'+'outputt/'+dir_list[mm])  # yha apn dusri dir mei file save krwa ke dekhre hai,isme khi
                                                                     # issue aata hai koi file mei toh use remove kr denge except use krke
                #print(im.shape,"sfs")
                #print(im,"dsf")
                count=count+1
                #print(dir_list[mm],'\n')
            else:
                print(file_path)
                os.remove(file_path)
            
    
   
    #print('file count:', count) 
    augmented_img = 700-count
    print(augmented_img,"for firsttt")
    if augmented_img<0:


        patth = '/content/Main_folder/train'

        ******
        for cls_name in (class_namess):
            for mp in range(abs(count)):
                paath = patth+'/'+cls_name+'/'
                file = dir_list[0]
                #path = os.path.join(patth, dir)
                path = os.path.join(paath, file)
                try:
                    os.remove(path)
                    print("% s removed successfully" % path)
                except OSError as error:
                    print(error)
                    print("File path can not be removed")
        ***

        
        for cls_name in (class_namess):
            pa = patth+'/'+cls_name
            qpp = os.listdir(pa)
            print(qpp,"sdfdsfsfg")
            #print(abs(count),"sdfd")

            for mp in range(abs(augmented_img)):
                #print(qpp,"sdfdsfsfg")
                randd = random.choice(qpp)
                #print(randd,"fdasd")
                tt = patth+'/'+cls_name+'/'+randd
                
                if os.path.exists(tt):
                    os.remove(patth+'/'+cls_name+'/'+randd)
                    #print(tt,"Sfdfd")
                else:
                    pass



        return (1)         
    elif count<700:
        return (augmented_img+1)
    else:
        return(1)
    
aug_img()
"""
# Out:
# '\n# Removing inculde but i m thinking like we can remove later\n\n\n# this function fix the number of augmented images and handle RGBA images, MAIN-------------------------------------------------\nimport os\nimport cv2\nfrom PIL import Image\nimport random\ndef aug_img():\n    \n    count = 0\n    dir_path = path_of_foldd              # that dir path\n    dir_list = (os.listdir(dir_path))            #file name of particular dir\n    \n    #print(dir_path)\n    #print((dir_list))\n    print(dir_list)\n    for mm in range(len(dir_list)):\n        #print(dir_list[mm])\n        #print(mm)\n        #print((dir_list))\n        if dir_list[mm]==\'output\':\n            pass\n        else:\n            #print(dir_path+dir_list[mm])\n            file_path = (dir_path+dir_list[mm])\n            #print(file_path,"\n")\n            \n            #print("kjhkn")\n            \n            im1 = Image.open(file_path,\'r\')\n                \n            if im1.mode == \'RGB\':\n                #
# ...

# %%
import os

pathh = "/content/Main_folder/train"
image_number=[]
disease =[]
for k in class_namess:
    full_path = pathh+'/'+k
    lst = os.listdir(full_path) # your directory path
    #print(lst,"sdffdfv")
    number_files = len(lst)
    image_number.append(number_files)
    disease.append(k)
    print(number_files," images in",k,"floder")
# Out:
# 1512  images in Apple Apple scab floder
# 1491  images in Apple Black rot floder
# 660  images in Apple Cedar apple rust floder
# 1233  images in Apple healthy floder
# 1126  images in Blueberry healthy floder
# 789  images in Cherry Powdery mildew floder
# 639  images in Cherry healthy floder
# 430  images in Corn Gray Leaf Spot floder
# 859  images in Corn Leaf Blight floder
# 979  images in Corn Leaf Common Rust floder
# 738  images in Corn Northern Leaf Blight floder
# 871  images in Corn healthy floder
# 885  images in Grape Black rot floder
# 1037  images in Grape Esca (Black Measles) floder
# 807  images in Grape Leaf blight (Isariopsis Leaf Spot) floder
# 317  images in Grape healthy floder
# 1881  images in Orange Haunglongbing (Citrus greening) floder
# 1722  images in Peach Bacterial spot floder
# 270  images in Peach healthy floder
# 747  images in Pepper bell Bacterial spot floder
# 1107  images in Pepper bell healthy floder
# 750  images in Potato Early blight floder
# ...

# %%
pip install Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import Augmentor

path_to_data = "/content/Main_folder/train"

for m in range(len(class_namess)):
    path_of_foldd = path_to_data+'/'+class_namess[m]+'/'
    print(path_of_foldd)
    
        
    p = Augmentor.Pipeline(path_of_foldd)
    p.rotate(probability=0.9, max_left_rotation=10, max_right_rotation=10)    #rotation
    p.zoom(probability=0.4, min_factor=1.1, max_factor=1.6)                  #zoom
    sp = aug_imgg()
    #print(sp,"testing")
    p.sample(sp)  #how many images u want to augment

            # probability parameter controls how often the operation is applied
# Out:
# /content/Main_folder/train/Apple Apple scab/
# Initialised with 1512 image(s) found.
# ...

# %%
# Run this cell only one tiime
from pathlib import Path
import shutil
import os

path_to_data = "/content/Main_folder/train"


for XD in range(len(class_namess)):
    path_of_new_img = path_to_data+'/'+class_namess[XD]+'/'+'output'+'/'
    path_of_fold = path_to_data+'/'+class_namess[XD]+'/'
     #print(path_of_fold)
     #print(path_of_new_img,'\n')
    files=os.listdir(path_of_new_img)

     # iterating over all the files in
     # the source directory
    for file_name in files:
       shutil.copy(path_of_new_img+file_name, path_of_fold+file_name)
    print("Files are copied successfully")
# Out:
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# Files are copied successfully
# ...

# %%
# For removing recently created folder

import shutil

path_to_data = "/content/Main_folder/train"

for lol in range(len(class_namess)):
    folder_path = path_to_data+'/'+class_namess[lol]+'/'+'output'+'/'                
    shutil.rmtree(folder_path)                                           # removing the new dir that is created during data augmentation
    
    #shutil.rmtree("C:/Users/Asus/Desktop/Omdena/jute_insect_data_all/train/Jute Stem Weevil/output/")
print("Successfully removed created folder")
# Out:
# Successfully removed created folder

# %%
import os

pathh = "/content/Main_folder/train"
image_number=[]
disease =[]
for k in class_namess:
    full_path = pathh+'/'+k
    lst = os.listdir(full_path) # your directory path
    #print(lst,"sdffdfv")
    number_files = len(lst)
    image_number.append(number_files)
    disease.append(k)
    print(number_files," images in",k,"floder")
# Out:
# 1513  images in Apple Apple scab floder
# 1492  images in Apple Black rot floder
# 701  images in Apple Cedar apple rust floder
# 1234  images in Apple healthy floder
# 1127  images in Blueberry healthy floder
# 790  images in Cherry Powdery mildew floder
# 701  images in Cherry healthy floder
# 701  images in Corn Gray Leaf Spot floder
# 860  images in Corn Leaf Blight floder
# 980  images in Corn Leaf Common Rust floder
# 739  images in Corn Northern Leaf Blight floder
# 872  images in Corn healthy floder
# 886  images in Grape Black rot floder
# 1038  images in Grape Esca (Black Measles) floder
# 808  images in Grape Leaf blight (Isariopsis Leaf Spot) floder
# 701  images in Grape healthy floder
# 1882  images in Orange Haunglongbing (Citrus greening) floder
# 1723  images in Peach Bacterial spot floder
# 701  images in Peach healthy floder
# 748  images in Pepper bell Bacterial spot floder
# 1108  images in Pepper bell healthy floder
# 751  images in Potato Early blight floder
# ...

# %%
# now we have to make 700 images in each folder
import random

pathh = "/content/Main_folder/train"
image_number=[]
disease =[]
for k in class_namess:
    full_path = pathh+'/'+k
    lpt = os.listdir(full_path) # your directory path
    #print(lpt,"sdffdfv")
    #print(full_path,"sdsa")
    loop_run = len(lpt)-700
    #print(loop_run)
    xs=0
    for _ in range(loop_run):
        #lpt = os.listdir(full_path)                # list of all files
        #qqq = random.choice(lpt)
        os.remove(full_path+'/'+lpt[xs])
        xs=xs+1
        #print(xs,"Sdfsf")
    #number_files = len(lst)
    #image_number.append(number_files)
    #disease.append(k)
    #print(number_files," images in",k,"floder")

# %%
import os

pathh = "/content/Main_folder/train"
image_number=[]
disease =[]
for k in class_namess:
    full_path = pathh+'/'+k
    lst = os.listdir(full_path) # your directory path
    #print(lst,"sdffdfv")
    number_files = len(lst)
    image_number.append(number_files)
    disease.append(k)
    print(number_files," images in",k,"floder")
# Out:
# 700  images in Apple Apple scab floder
# 700  images in Apple Black rot floder
# 700  images in Apple Cedar apple rust floder
# 700  images in Apple healthy floder
# 700  images in Blueberry healthy floder
# 700  images in Cherry Powdery mildew floder
# 700  images in Cherry healthy floder
# 700  images in Corn Gray Leaf Spot floder
# 700  images in Corn Leaf Blight floder
# 700  images in Corn Leaf Common Rust floder
# 700  images in Corn Northern Leaf Blight floder
# 700  images in Corn healthy floder
# 700  images in Grape Black rot floder
# 700  images in Grape Esca (Black Measles) floder
# 700  images in Grape Leaf blight (Isariopsis Leaf Spot) floder
# 700  images in Grape healthy floder
# 700  images in Orange Haunglongbing (Citrus greening) floder
# 700  images in Peach Bacterial spot floder
# 700  images in Peach healthy floder
# 700  images in Pepper bell Bacterial spot floder
# 700  images in Pepper bell healthy floder
# 700  images in Potato Early blight floder
# ...

# %%
# spliting val folder into test and validation

def get_dataset_partitionn_tf(ds,val_split=0.5,test_split=0.5, shuffle = True, shuffle_size=10000):
    
    ds_size = len(ds)
    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)
    
    val_size = int(val_split*ds_size)
    
    val_ds = ds.take(val_size)
    test_ds = ds.skip(val_size)
    
    return val_ds,test_ds

# %%
val_ds,test_ds = get_dataset_partitionn_tf(dataset3,val_split = 0.5,test_split=0.5)

# %%
len(val_ds)
# Out:
# 197

# %%
len(test_ds)
# Out:
# 198

# %%
# prefetch, resize and rescale
train_ds = dataset2.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_rescale =tf.keras.Sequential([
    layers.experimental.preprocessing.Resizing(IMAGE_SIZE,IMAGE_SIZE),
    layers.experimental.preprocessing.Rescaling(1.0/255),   
    
])
